# %% [markdown]
# # Importing Dependencies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Collection

# %%
#loading the dataset
import pandas as pd
wine = pd.read_excel('wine_quality.xlsx')

# %%
wine
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
#first 5 rows of the dataset
wine.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
#last 5 rows of the dataset
wine.tail()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6

# %%
#checking the number of rows and columns of the dataset
wine.shape
# Out:
# (6497, 13)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Checking the null values in our dataset

# %%
wine.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %% [markdown]
# # Dropping the missing values

# %%
wine.dropna(inplace=True)
wine
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6491    red            6.8             0.620         0.08             1.9
# 6492    red            6.2             0.600         0.08             2.0
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6491      0.068                 28.0                  38.0  0.99651  3.42
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6491       0.82      9.5        6
# 6492       0.58     10.5        5
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6463 rows x 13 columns]

# %%
#reseting the index after dropping missing values
wine.reset_index()
# Out:
#       index   type  fixed acidity  volatile acidity  citric acid  \
# 0         0  white            7.0             0.270         0.36
# 1         1  white            6.3             0.300         0.34
# 2         2  white            8.1             0.280         0.40
# 3         3  white            7.2             0.230         0.32
# 4         4  white            7.2             0.230         0.32
# ...     ...    ...            ...               ...          ...
# 6458   6491    red            6.8             0.620         0.08
# 6459   6492    red            6.2             0.600         0.08
# 6460   6494    red            6.3             0.510         0.13
# 6461   6495    red            5.9             0.645         0.12
# 6462   6496    red            6.0             0.310         0.47
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0               20.7      0.045                 45.0                 170.0
# 1                1.6      0.049                 14.0                 132.0
# 2                6.9      0.050                 30.0                  97.0
# 3                8.5      0.058                 47.0                 186.0
# 4                8.5      0.058                 47.0                 186.0
# ...              ...        ...                  ...                   ...
# 6458             1.9      0.068                 28.0                  38.0
# 6459             2.0      0.090                 32.0                  44.0
# 6460             2.3      0.076                 29.0                  40.0
# 6461             2.0      0.075                 32.0                  44.0
# 6462             3.6      0.067                 18.0                  42.0
#
#       density    pH  sulphates  alcohol  quality
# 0     1.00100  3.00       0.45      8.8        6
# 1     0.99400  3.30       0.49      9.5        6
# 2     0.99510  3.26       0.44     10.1        6
# 3     0.99560  3.19       0.40      9.9        6
# 4     0.99560  3.19       0.40      9.9        6
# ...       ...   ...        ...      ...      ...
# 6458  0.99651  3.42       0.82      9.5        6
# 6459  0.99490  3.45       0.58     10.5        5
# 6460  0.99574  3.42       0.75     11.0        6
# 6461  0.99547  3.57       0.71     10.2        5
# 6462  0.99549  3.39       0.66     11.0        6
#
# [6463 rows x 14 columns]

# %% [markdown]
# # Checking the duplicate values from the dataset

# %%
wine[wine.duplicated()]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 4     white            7.2             0.230         0.32            8.50
# 5     white            8.1             0.280         0.40            6.90
# 7     white            7.0             0.270         0.36           20.70
# 8     white            6.3             0.300         0.34            1.60
# 39    white            7.3             0.240         0.39           17.95
# ...     ...            ...               ...          ...             ...
# 6461    red            7.2             0.695         0.13            2.00
# 6462    red            7.2             0.695         0.13            2.00
# 6465    red            7.2             0.695         0.13            2.00
# 6479    red            6.2             0.560         0.09            1.70
# 6494    red            6.3             0.510         0.13            2.30
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 4         0.058                 47.0                 186.0  0.99560  3.19
# 5         0.050                 30.0                  97.0  0.99510  3.26
# 7         0.045                 45.0                 170.0  1.00100  3.00
# 8         0.049                 14.0                 132.0  0.99400  3.30
# 39        0.057                 45.0                 149.0  0.99990  3.21
# ...         ...                  ...                   ...      ...   ...
# 6461      0.076                 12.0                  20.0  0.99546  3.29
# 6462      0.076                 12.0                  20.0  0.99546  3.29
# 6465      0.076                 12.0                  20.0  0.99546  3.29
# 6479      0.053                 24.0                  32.0  0.99402  3.54
# 6494      0.076                 29.0                  40.0  0.99574  3.42
#
#       sulphates  alcohol  quality
# 4          0.40      9.9        6
# 5          0.44     10.1        6
# 7          0.45      8.8        6
# 8          0.49      9.5        6
# 39         0.36      8.6        5
# ...         ...      ...      ...
# 6461       0.54     10.1        5
# 6462       0.54     10.1        5
# 6465       0.54     10.1        5
# 6479       0.60     11.3        5
# 6494       0.75     11.0        6
#
# [1168 rows x 13 columns]

# %% [markdown]
# # So we can see there are too many duplicate values. Now we will drop the duplicate values.

# %% [markdown]
# # Dropping the Duplicate Values

# %%
wine.drop_duplicates(inplace=True)
wine
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 6     white            6.2             0.320         0.16             7.0
# ...     ...            ...               ...          ...             ...
# 6490    red            6.3             0.510         0.13             2.3
# 6491    red            6.8             0.620         0.08             1.9
# 6492    red            6.2             0.600         0.08             2.0
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 6         0.045                 30.0                 136.0  0.99490  3.18
# ...         ...                  ...                   ...      ...   ...
# 6490      0.076                 29.0                  40.0  0.99574  3.42
# 6491      0.068                 28.0                  38.0  0.99651  3.42
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 6          0.47      9.6        6
# ...         ...      ...      ...
# 6490       0.75     11.0        6
# 6491       0.82      9.5        6
# 6492       0.58     10.5        5
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [5295 rows x 13 columns]

# %%
#reseting the index after dropping duplicate values
wine.reset_index()
# Out:
#       index   type  fixed acidity  volatile acidity  citric acid  \
# 0         0  white            7.0             0.270         0.36
# 1         1  white            6.3             0.300         0.34
# 2         2  white            8.1             0.280         0.40
# 3         3  white            7.2             0.230         0.32
# 4         6  white            6.2             0.320         0.16
# ...     ...    ...            ...               ...          ...
# 5290   6490    red            6.3             0.510         0.13
# 5291   6491    red            6.8             0.620         0.08
# 5292   6492    red            6.2             0.600         0.08
# 5293   6495    red            5.9             0.645         0.12
# 5294   6496    red            6.0             0.310         0.47
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0               20.7      0.045                 45.0                 170.0
# 1                1.6      0.049                 14.0                 132.0
# 2                6.9      0.050                 30.0                  97.0
# 3                8.5      0.058                 47.0                 186.0
# 4                7.0      0.045                 30.0                 136.0
# ...              ...        ...                  ...                   ...
# 5290             2.3      0.076                 29.0                  40.0
# 5291             1.9      0.068                 28.0                  38.0
# 5292             2.0      0.090                 32.0                  44.0
# 5293             2.0      0.075                 32.0                  44.0
# 5294             3.6      0.067                 18.0                  42.0
#
#       density    pH  sulphates  alcohol  quality
# 0     1.00100  3.00       0.45      8.8        6
# 1     0.99400  3.30       0.49      9.5        6
# 2     0.99510  3.26       0.44     10.1        6
# 3     0.99560  3.19       0.40      9.9        6
# 4     0.99490  3.18       0.47      9.6        6
# ...       ...   ...        ...      ...      ...
# 5290  0.99574  3.42       0.75     11.0        6
# 5291  0.99651  3.42       0.82      9.5        6
# 5292  0.99490  3.45       0.58     10.5        5
# 5293  0.99547  3.57       0.71     10.2        5
# 5294  0.99549  3.39       0.66     11.0        6
#
# [5295 rows x 14 columns]

# %%
wine.shape
# Out:
# (5295, 13)

# %% [markdown]
# # Data Analysis and Visuallization

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5295 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  5295 non-null   object
#  1   fixed acidity         5295 non-null   float64
#  2   volatile acidity      5295 non-null   float64
#  3   citric acid           5295 non-null   float64
#  4   residual sugar        5295 non-null   float64
#  5   chlorides             5295 non-null   float64
#  6   free sulfur dioxide   5295 non-null   float64
#  7   total sulfur dioxide  5295 non-null   float64
#  8   density               5295 non-null   float64
#  9   pH                    5295 non-null   float64
#  10  sulphates             5295 non-null   float64
#  11  alcohol               5295 non-null   float64
#  12  quality               5295 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 579.1+ KB

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    5295.000000       5295.000000  5295.000000     5295.000000
# mean        7.218008          0.344021     0.318782        5.051029
# std         1.320690          0.168237     0.147112        4.500641
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.240000        1.800000
# 50%         7.000000          0.300000     0.310000        2.700000
# 75%         7.700000          0.410000     0.400000        7.500000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  5295.000000          5295.000000           5295.000000  5295.000000
# mean      0.056690            30.046837            114.118225     0.994536
# std       0.036901            17.827151             56.787187     0.002969
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            16.000000             74.000000     0.992200
# 50%       0.047000            28.000000            116.000000     0.994670
# 75%       0.066000            41.000000            154.000000     0.996780
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  5295.000000  5295.000000  5295.000000  5295.000000
# mean      3.224385     0.533199    10.550154     5.796034
# std       0.160155     0.149851     1.186533     0.880005
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.400000     6.000000
# 75%       3.330000     0.600000    11.400000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
#percentage of white and red wine
count=wine['type'].value_counts(normalize=True)
count
# Out:
# white    0.744476
# red      0.255524
# Name: type, dtype: float64

# %%
fig=plt.figure(figsize=(4,4))
plt.title("Visualization of Types of Wine")
sns.countplot(x="type", data=wine, color='green', alpha=0.5, width=0.5)
# Out:
# <Axes: title={'center': 'Visualization of Types of Wine'}, xlabel='type', ylabel='count'>

# %%
#Checking distribution and outlier for alcohol
plt.figure(4)
plt.subplot(121)
plt.title("Distplot")
sns.distplot(wine['alcohol'])
plt.subplot(122)
plt.title("Boxplot")
wine['alcohol'].plot.box(figsize=(8,4))
# Out:
# <Axes: title={'center': 'Boxplot'}>

# %%
#HISTOGRAM 
fig=plt.figure(figsize=(5,5))
ax1=plt.subplot()
plt.title("Citric Acid Visualization")
plt.xlabel("Values of Citric Acid")
plt.ylabel("Count of citric acid")
ax1.hist(data=wine,x='citric acid', alpha=1)
plt.show()

# %%
# Wine Quality comparision with different chemical parameters

fig, axes = plt.subplots(3, 3, figsize=(18, 10))
fig.suptitle('Quality comparison with different parameters')
sns.barplot(ax=axes[0, 0], data=wine, x='quality', y='fixed acidity')
sns.barplot(ax=axes[0, 1], data=wine, x='quality', y='volatile acidity')
sns.barplot(ax=axes[0, 2], data=wine, x='quality', y='citric acid')
sns.barplot(ax=axes[1, 0], data=wine, x='quality', y='alcohol')
sns.barplot(ax=axes[1, 1], data=wine, x='quality', y='residual sugar')
sns.barplot(ax=axes[1, 2], data=wine, x='quality', y='pH')
sns.barplot(ax=axes[2, 0], data=wine, x='quality', y='density')
sns.barplot(ax=axes[2, 1], data=wine, x='quality', y='sulphates')
sns.barplot(ax=axes[2, 2], data=wine, x='quality', y='total sulfur dioxide')
# Out:
# <Axes: xlabel='quality', ylabel='total sulfur dioxide'>

# %%
#PIE CHART
num=[74.44, 25.55]
labels=['White Wine', 'Red Wine']
explode=[0,0.05]
fig=plt.figure(figsize=(5,5))
color=['lightgrey','red']
plt.title("Percentage of Production of Wine")
plt.pie(num,labels=labels, explode=explode, shadow=True, colors=color, autopct="%1.1f%%")
plt.legend(title="Types of Wine")
plt.show()

# %%
#sns.pairplot(wine)

# %% [markdown]
# # CORRELATION

# %%
#checking correlation
correlation= wine.corr()
correlation
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.216524     0.329252
# volatile acidity           0.216524          1.000000    -0.382750
# citric acid                0.329252         -0.382750     1.000000
# residual sugar            -0.106084         -0.164438     0.146528
# chlorides                  0.289903          0.368266     0.055266
# free sulfur dioxide       -0.282025         -0.349784     0.130802
# total sulfur dioxide      -0.328631         -0.401231     0.194231
# density                    0.478920          0.308416     0.095824
# pH                        -0.269624          0.245329    -0.342648
# sulphates                  0.307044          0.226537     0.062121
# alcohol                   -0.103657         -0.066781    -0.005124
# quality                   -0.079599         -0.265214     0.097926
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.106084   0.289903            -0.282025
# volatile acidity           -0.164438   0.368266            -0.349784
# citric acid                 0.146528   0.055266             0.130802
# residual sugar              1.000000  -0.123115             0.399579
# chlorides                  -0.123115   1.000000            -0.187312
# free sulfur dioxide         0.399579  -0.187312             1.000000
# total sulfur dioxide        0.487534  -0.270009             0.721308
# density                     0.520194   0.372126             0.005827
# pH                         -0.233319   0.025963            -0.141368
# sulphates                  -0.174663   0.405771            -0.199005
# alcohol                    -0.305311  -0.270196            -0.169854
# quality                    -0.054625  -0.202016             0.053786
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.328631  0.478920 -0.269624   0.307044
# volatile acidity                 -0.401231  0.308416  0.245329   0.226537
# citric acid                       0.194231  0.095824 -0.342648   0.062121
# residual sugar                    0.487534  0.520194 -0.233319  -0.174663
# chlorides                        -0.270009  0.372126  0.025963   0.405771
# free sulfur dioxide               0.721308  0.005827 -0.141368  -0.199005
# total sulfur dioxide              1.000000  0.005974 -0.222003  -0.275389
# density                           0.005974  1.000000  0.034979   0.283042
# pH                               -0.222003  0.034979  1.000000   0.166139
# sulphates                        -0.275389  0.283042  0.166139   1.000000
# alcohol                          -0.247779 -0.668950  0.096615  -0.019008
# quality                          -0.050728 -0.325338  0.038903   0.041806
#
#                        alcohol   quality
# fixed acidity        -0.103657 -0.079599
# volatile acidity     -0.066781 -0.265214
# citric acid          -0.005124  0.097926
# residual sugar       -0.305311 -0.054625
# chlorides            -0.270196 -0.202016
# free sulfur dioxide  -0.169854  0.053786
# total sulfur dioxide -0.247779 -0.050728
# density              -0.668950 -0.325338
# pH                    0.096615  0.038903
# sulphates            -0.019008  0.041806
# alcohol               1.000000  0.470143
# quality               0.470143  1.000000

# %%
#buidling heatmap
plt.figure(figsize=(10,10))
sns.heatmap(correlation, 
            cbar=True, 
            square=True, 
            fmt= '.1f', 
            annot=True, 
            annot_kws={'size': 8}, 
            cmap='Greens')
# Out:
# <Axes: >

# %% [markdown]
# # Data Preprocessing

# %%
#getting unique values for the type of wine
wine['type'].unique()
# Out:
# array(['white', 'red'], dtype=object)

# %%
#map function for converting in numerical values
wine['type']=wine['type'].map({'white':0, 'red':1})

# %%
wine
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 6        0            6.2             0.320         0.16             7.0
# ...    ...            ...               ...          ...             ...
# 6490     1            6.3             0.510         0.13             2.3
# 6491     1            6.8             0.620         0.08             1.9
# 6492     1            6.2             0.600         0.08             2.0
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 6         0.045                 30.0                 136.0  0.99490  3.18
# ...         ...                  ...                   ...      ...   ...
# 6490      0.076                 29.0                  40.0  0.99574  3.42
# 6491      0.068                 28.0                  38.0  0.99651  3.42
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 6          0.47      9.6        6
# ...         ...      ...      ...
# 6490       0.75     11.0        6
# 6491       0.82      9.5        6
# 6492       0.58     10.5        5
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [5295 rows x 13 columns]

# %% [markdown]
# # Seprating target value from dataset

# %%
X=wine.iloc[::-1]
Y=wine.iloc[:,-1]

# %%
X
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6496     1            6.0             0.310         0.47             3.6
# 6495     1            5.9             0.645         0.12             2.0
# 6492     1            6.2             0.600         0.08             2.0
# 6491     1            6.8             0.620         0.08             1.9
# 6490     1            6.3             0.510         0.13             2.3
# ...    ...            ...               ...          ...             ...
# 6        0            6.2             0.320         0.16             7.0
# 3        0            7.2             0.230         0.32             8.5
# 2        0            8.1             0.280         0.40             6.9
# 1        0            6.3             0.300         0.34             1.6
# 0        0            7.0             0.270         0.36            20.7
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6496      0.067                 18.0                  42.0  0.99549  3.39
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6491      0.068                 28.0                  38.0  0.99651  3.42
# 6490      0.076                 29.0                  40.0  0.99574  3.42
# ...         ...                  ...                   ...      ...   ...
# 6         0.045                 30.0                 136.0  0.99490  3.18
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 0         0.045                 45.0                 170.0  1.00100  3.00
#
#       sulphates  alcohol  quality
# 6496       0.66     11.0        6
# 6495       0.71     10.2        5
# 6492       0.58     10.5        5
# 6491       0.82      9.5        6
# 6490       0.75     11.0        6
# ...         ...      ...      ...
# 6          0.47      9.6        6
# 3          0.40      9.9        6
# 2          0.44     10.1        6
# 1          0.49      9.5        6
# 0          0.45      8.8        6
#
# [5295 rows x 13 columns]

# %%
Y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 6       6
#        ..
# 6490    6
# 6491    6
# 6492    5
# 6495    5
# 6496    6
# Name: quality, Length: 5295, dtype: int64

# %%
X = wine.drop('quality',axis=1)

# %%
X
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 6        0            6.2             0.320         0.16             7.0
# ...    ...            ...               ...          ...             ...
# 6490     1            6.3             0.510         0.13             2.3
# 6491     1            6.8             0.620         0.08             1.9
# 6492     1            6.2             0.600         0.08             2.0
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 6         0.045                 30.0                 136.0  0.99490  3.18
# ...         ...                  ...                   ...      ...   ...
# 6490      0.076                 29.0                  40.0  0.99574  3.42
# 6491      0.068                 28.0                  38.0  0.99651  3.42
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol
# 0          0.45      8.8
# 1          0.49      9.5
# 2          0.44     10.1
# 3          0.40      9.9
# 6          0.47      9.6
# ...         ...      ...
# 6490       0.75     11.0
# 6491       0.82      9.5
# 6492       0.58     10.5
# 6495       0.71     10.2
# 6496       0.66     11.0
#
# [5295 rows x 12 columns]

# %%
Y= wine['quality'].apply(lambda y: 1 if y > 7 else 0)
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 6       0
#        ..
# 6490    0
# 6491    0
# 6492    0
# 6495    0
# 6496    0
# Name: quality, Length: 5295, dtype: int64

# %%
wine['quality'].value_counts()
# Out:
# 6    2311
# 5    1745
# 7     852
# 4     204
# 8     148
# 3      30
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X)
x_standard = scaler.transform(X)

# %%
x_standard
# Out:
# array([[-0.5858556 , -0.16508655, -0.4400209 , ..., -1.40118575,
#         -0.55526714, -1.47515354],
#        [-0.5858556 , -0.69516261, -0.26168411, ...,  0.47218021,
#         -0.28830936, -0.88514391],
#        [-0.5858556 ,  0.66789012, -0.38057531, ...,  0.22239808,
#         -0.62200659, -0.37942137],
#        ...,
#        [ 1.70690524, -0.77088777,  1.52168375, ...,  1.40886318,
#          0.31234565, -0.04227301],
#        [ 1.70690524, -0.99806322,  1.78918893, ...,  2.15820957,
#          1.17995844, -0.29513428],
#        [ 1.70690524, -0.92233807, -0.20223852, ...,  1.03418999,
#          0.84626121,  0.37916244]])

# %% [markdown]
# # Train & Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=.2,random_state=123)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (4236, 12)
# (1059, 12)
# (4236,)
# (1059,)

# %%
X_test
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1340     0            7.2             0.160         0.32             0.8
# 1164     0            8.2             0.230         0.49             0.9
# 5902     1            8.2             0.430         0.29             1.6
# 2450     0            6.6             0.560         0.15            10.0
# 5899     1            9.9             0.350         0.38             1.5
# ...    ...            ...               ...          ...             ...
# 648      0            6.0             0.320         0.12             5.9
# 999      0            7.6             0.210         0.60             2.1
# 2360     0            8.1             0.250         0.34            10.1
# 5880     1            7.3             0.520         0.32             2.1
# 4109     0            5.0             0.255         0.22             2.7
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 1340      0.040                 50.0                 121.0  0.99220  3.27
# 1164      0.057                 15.0                  73.0  0.99280  3.07
# 5902      0.081                 27.0                  45.0  0.99603  3.25
# 2450      0.037                 38.0                 157.0  0.99642  3.28
# 5899      0.058                 31.0                  47.0  0.99676  3.26
# ...         ...                  ...                   ...      ...   ...
# 648       0.041                 34.0                 190.0  0.99440  3.16
# 999       0.046                 47.0                 165.0  0.99360  3.05
# 2360      0.050                 30.0                 121.0  0.99724  3.17
# 5880      0.070                 51.0                  70.0  0.99418  3.34
# 4109      0.043                 46.0                 153.0  0.99238  3.75
#
#       sulphates  alcohol
# 1340       0.33     10.0
# 1164       0.38     10.4
# 5902       0.54     10.3
# 2450       0.52      9.4
# 5899       0.82     10.6
# ...         ...      ...
# 648        0.72     10.0
# 999        0.54     10.1
# 2360       0.49     10.1
# 5880       0.82     12.9
# 4109       0.76     11.3
#
# [1059 rows x 12 columns]

# %%
Y_train
# Out:
# 1501    0
# 2126    0
# 3681    1
# 6396    0
# 3938    0
#        ..
# 6406    0
# 5028    0
# 1615    0
# 4306    0
# 4479    0
# Name: quality, Length: 4236, dtype: int64

# %%
Y_test
# Out:
# 1340    0
# 1164    0
# 5902    0
# 2450    0
# 5899    0
#        ..
# 648     0
# 999     0
# 2360    0
# 5880    0
# 4109    0
# Name: quality, Length: 1059, dtype: int64

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test)

# %% [markdown]
# # MODEL EVALUATION

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test, y_pred)
# Out:
# 0.9707271010387157

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      1028
#            1       0.00      0.00      0.00        31
#
#     accuracy                           0.97      1059
#    macro avg       0.49      0.50      0.49      1059
# weighted avg       0.94      0.97      0.96      1059

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(Y_test, y_pred)
# Out:
# array([[1028,    0],
#        [  31,    0]], dtype=int64)

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
style.use('classic')
cm = confusion_matrix(Y_test, y_pred, labels=logreg.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix= cm, display_labels=logreg.classes_)
disp.plot()

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtree_pred = dtree.predict(X_test)

# %% [markdown]
# # MODEL EVALUATION

# %%
dtree_acc = accuracy_score(dtree_pred, Y_test)

# %%
print("Test accuracy: {:.2f}%".format(dtree_acc*100))
# Out:
# Test accuracy: 93.86%

# %%
print(classification_report(Y_test, dtree_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      1028
#            1       0.07      0.10      0.08        31
#
#     accuracy                           0.94      1059
#    macro avg       0.52      0.53      0.53      1059
# weighted avg       0.95      0.94      0.94      1059

# %%
style.use('classic')
cm = confusion_matrix(Y_test, dtree_pred, labels=dtree.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix= cm, display_labels=dtree.classes_)
disp.plot()

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # MODEL EVALUATION

# %%
# accuracy on test data
rfc.pred = rfc.predict(X_test)
rfc.accuracy = accuracy_score(rfc.pred, Y_test)

# %%
print('Accuracy : ', rfc.accuracy)
# Out:
# Accuracy :  0.9716713881019831

# %%
print(classification_report(Y_test, rfc.pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      1028
#            1       1.00      0.03      0.06        31
#
#     accuracy                           0.97      1059
#    macro avg       0.99      0.52      0.52      1059
# weighted avg       0.97      0.97      0.96      1059

# %%
confusion_matrix(Y_test, rfc.pred)
# Out:
# array([[1028,    0],
#        [  30,    1]], dtype=int64)

# %%
style.use('classic')
cm = confusion_matrix(Y_test, rfc.pred, labels=rfc.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix= cm, display_labels=rfc.classes_)
disp.plot()

# %%
rfc.feature_importances_
# Out:
# array([0.00166689, 0.08246876, 0.09178683, 0.07635301, 0.0892983 ,
#        0.08025472, 0.09496822, 0.09168494, 0.09816997, 0.09481734,
#        0.0933839 , 0.10514712])

# %%
pd.Series(rfc.feature_importances_,index=wine.drop('quality',axis=1).columns).plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# # Model Deployment

# %%
input_data = (1,6.5,0.2,0.35,7.1,0.81,15.0,107.0,0.9878,3.38,0.9,0.2)

# changing the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the data as we are predicting the label for only one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = rfc.predict(input_data_reshaped)
print(prediction)

if (prediction[0]==1):
  print('Good Quality Wine')
else:
  print('Bad Quality Wine')
# Out:
# [0]
# Bad Quality Wine

# %%
input_data = (1, 6.8,0.26,0.42,1.7,0.049,41,122,0.993,3.47,0.48,10.5)


# changing the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the data as we are predicting the label for only one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = rfc.predict(input_data_reshaped)
print(prediction)

if (prediction[0]==1):
  print('Good Quality Wine')
else:
  print('Bad Quality Wine')
# Out:
# [1]
# Good Quality Wine

# %%
x = np.array(["LR", "DT", "RFC"])
y = np.array([95,93,97])
fig=plt.figure(figsize=(5,5))
ax1=plt.subplot()
ax1.barh(x,y, color='g', alpha=1, height = 0.2)
plt.xlabel('Accuracy Score')
plt.ylabel('Model Name')
plt.title('Accuracy Evaluation of different metricies')
#plt.bar(x,y)
plt.show()
